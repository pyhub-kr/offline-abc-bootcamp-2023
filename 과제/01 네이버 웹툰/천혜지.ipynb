# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://m.comic.naver.com/webtoon/list?titleId=747269"

# %%
headers = {
    "User-Agent": "https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid1=103&sid2=238"
}

# %%
res = requests.get(url, headers = headers)
res
# Out:
# <Response [200]>

# %%
html = res.text
len(html)
# Out:
# 49036

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
tag_list = soup.select(".preview a")

# %%
len(tag_list)
# Out:
# 30

# %%
tag = tag_list[0]

# %%
tag["href"]
# Out:
# '/webtoon/detail?titleId=747269&no=163&week=wed&listSortOrder=DESC&listPage=1'

# %%
res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t\n\n\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta http-equiv="Content-Type" content="text/html;charset=utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="format-detection" content="telephone=no">\n\n\n<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/comic/im/favicon/1804/webtoon_favicon_32x32.ico" type="image/x-icon">\n\n    \n    \n\n\n\t<title>전지적 독자 시점 :: 네이버 웹툰</title>\n\t\n\n\n\n\n<meta property="og:title" content="전지적 독자 시점" />\n\n    \n        \n        \n            \n                \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n            \n     
# ...

# %%
html = res.text
len(html)
# Out:
# 49036

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "html.parser") # 기본 파서 html.parser

# %%
soup.select('a')
# Out:
# [<a href="#ct">본문 바로가기</a>,
#  <a class="gnb_logo" href="http://m.naver.com" onclick="nclk_v2(event,'gnb.naver')"><span class="blind">네이버</span></a>,
#  <a class="title_header_toon" href="/index" onclick="nclk_v2(event,'gnb.comic')">웹툰</a>,
#  <a class="title_header_sub" href="https://m.novel.naver.com" onclick="nclk_v2(event,'gnb.novel')">웹소설</a>,
#  <a class="title_header_sub" href="https://m.series.naver.com" onclick="nclk_v2(event, 'gnb.series')">시리즈</a>,
#  <a class="btn_search_header" href="/search/main" onclick="nclk_v2(event,'gnb.search')"><span class="blind">검색페이지 이동</span></a>,
#  <a class="btn_mypage_header" href="/mypage/favorite" onclick="nclk_v2(event,'gnb.my')"><span class="blind">MY</span></a>,
#  <a class="link" href="/index" onclick="nclk_v2(event,'lnb.home')"><span class="text">홈</span></a>,
#  <a class="link" href="/webtoon/weekday" onclick="nclk_v2(event,'lnb.weekday')"><span class="text">요일별</span></a>,
# ...

# %%
for tag in tag_list:
    link = tag["href"]
    label = tag.text.strip()
    # if label:
    if len(label) > 0:
        print(label)
        print(link)
        print()
# Out:
# 162. Ep. 28 최강의 희생양 (6)
#
#
#
# 9.96
# 23.07.18
# /webtoon/detail?titleId=747269&no=163&week=wed&listSortOrder=DESC&listPage=1
#
# 161. Ep. 28 최강의 희생양 (5)
#
#
#
# 9.96
# 23.07.11
# /webtoon/detail?titleId=747269&no=162&week=wed&listSortOrder=DESC&listPage=1
#
# 160. Ep. 28 최강의 희생양 (4)
#
#
#
# 9.90
# 23.07.04
# /webtoon/detail?titleId=747269&no=161&week=wed&listSortOrder=DESC&listPage=1
#
# 159. Ep. 28 최강의 희생양 (3)
#
#
#
# 9.97
# 23.06.27
# /webtoon/detail?titleId=747269&no=160&week=wed&listSortOrder=DESC&listPage=1
#
# 158. Ep. 28 최강의 희생양 (2)
#
#
#
# 9.96
# 23.06.20
# /webtoon/detail?titleId=747269&no=159&week=wed&listSortOrder=DESC&listPage=1
#
# 157. Ep. 28 최강의 희생양 (1)
#
#
#
# 9.96
# 23.06.13
# /webtoon/detail?titleId=747269&no=158&week=wed&listSortOrder=DESC&listPage=1
#
# 156. Ep. 27 읽을 수 없는 것 (4)
#
#
#
# 9.97
# 23.06.06
# /webtoon/detail?titleId=747269&no=157&week=wed&listSortOrder=DESC&listPage=1
#
# 155. Ep. 27 읽을 수 없는 것 (3)
#
#
#
# 9.97
# 23.05.30
# ...

# %%
for tag in tag_list:
    link = tag["href"]
    label = tag.text.strip()
    # if label:
    if len(label) > 0:
        print(label)
        print("https://m.comic.naver.com"+link)
        print()
# Out:
# 162. Ep. 28 최강의 희생양 (6)
#
#
#
# 9.96
# 23.07.18
# https://m.comic.naver.com/webtoon/detail?titleId=747269&no=163&week=wed&listSortOrder=DESC&listPage=1
#
# 161. Ep. 28 최강의 희생양 (5)
#
#
#
# 9.96
# 23.07.11
# https://m.comic.naver.com/webtoon/detail?titleId=747269&no=162&week=wed&listSortOrder=DESC&listPage=1
#
# 160. Ep. 28 최강의 희생양 (4)
#
#
#
# 9.90
# 23.07.04
# https://m.comic.naver.com/webtoon/detail?titleId=747269&no=161&week=wed&listSortOrder=DESC&listPage=1
#
# 159. Ep. 28 최강의 희생양 (3)
#
#
#
# 9.97
# 23.06.27
# https://m.comic.naver.com/webtoon/detail?titleId=747269&no=160&week=wed&listSortOrder=DESC&listPage=1
#
# 158. Ep. 28 최강의 희생양 (2)
#
#
#
# 9.96
# 23.06.20
# https://m.comic.naver.com/webtoon/detail?titleId=747269&no=159&week=wed&listSortOrder=DESC&listPage=1
#
# 157. Ep. 28 최강의 희생양 (1)
#
#
#
# 9.96
# 23.06.13
# https://m.comic.naver.com/webtoon/detail?titleId=747269&no=158&week=wed&listSortOrder=DESC&listPage=1
#
# 156. Ep. 27 읽을 수 없는 것 (4)
#
#
#
# 9.97
# 23.06.06
# ...

# %%
res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %%
tag = tag_list[0]
tag
# Out:
# <img alt="162. Ep. 28 최강의 희생양 (6)" height="45" src="https://image-comic.pstatic.net/webtoon/747269/163/thumbnail_202x120_55259f5d-05ce-435a-a9e4-316d7220f5ce.jpg" width="76"/>

# %%
tag["src"]
# Out:
# 'https://image-comic.pstatic.net/webtoon/747269/163/thumbnail_202x120_55259f5d-05ce-435a-a9e4-316d7220f5ce.jpg'

# %%
from tqdm.notebook import tqdm
import os

웹툰명 = "전독시"
for idx, tag in tqdm(enumerate(tag_list, 1)):
    image_url = tag["src"]
    image_filepath = f"{웹툰명}/{idx}/{idx:03d}.jpg"
    
    dirpath = os.path.dirname(image_filepath)
    os.makedirs(dirpath, exist_ok = True)
    
    image_res = requests.get(tag["src"], headers=headers)

    # 저장
    with open(image_filepath, "wb") as f:
        f.write(image_res.content)
# Out:
# 0it [00:00, ?it/s]
