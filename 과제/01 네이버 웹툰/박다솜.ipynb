# %%
import requests
from bs4 import BeautifulSoup

# %%
page_url = "https://m.comic.naver.com/webtoon/list?titleId=183559"

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}

# %%
res = requests.get(page_url, headers=headers)
res
# Out:
# <Response [200]>

# %%
html =res.text
len(html)
# Out:
# 50439

# %%
res.content
# Out:
# b'\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t\n\n\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta http-equiv="Content-Type" content="text/html;charset=utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="format-detection" content="telephone=no">\n\n\n<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/comic/im/favicon/1804/webtoon_favicon_32x32.ico" type="image/x-icon">\n\n    \n    \n        <link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static/m/comic/im/favicon/1804/ios_152x152.png"/>\n    \n\n\n\t<title>\xec\x8b\xa0\xec\x9d\x98 \xed\x83\x91 :: \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\x9b\xb9\xed\x88\xb0</title>\n\t\n\n\n\n\n<meta property="og:title" content="\x
# ...

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
tag_list = soup.select(".preview a") # .select는 태그 리스트를 반환
len(tag_list)
# Out:
# 30

# %%
tag =  tag_list[0]
print(repr(tag.select(".name")[0].text))
# Out:
# '3부 156화'

# %%
website = "https://m.comic.naver.com" + tag["href"]
website
# Out:
# 'https://m.comic.naver.com/webtoon/detail?titleId=183559&no=575&week=mon&listSortOrder=DESC&listPage=1'

# %%
for tag in tag_list:
    link = "https://m.comic.naver.com" + tag["href"]

    if label:
    #if len(label)>0:
        print((repr(tag.select(".name")[0].text)))           # if값 언제 참이고 언제 거짓일것인가 => 빈문자열은 거짓 -> 문자가 하나라도 있으면 참
        print(link)                                          # repr은 값 자체의 고유 데이터를 디테일하게 보여주는 것
        print()
# Out:
# '3부 156화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=575&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 155화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=574&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 154화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=573&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 153화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=572&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 152화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=571&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 151화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=570&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 150화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=569&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 149화'
# https://m.comic.naver.com/webtoon/detail?titleId=183559&no=568&week=mon&listSortOrder=DESC&listPage=1
#
# '3부 148화'
# ...

# %%
img_url = "https://m.comic.naver.com/webtoon/list?titleId=183559"

res = requests.get(img_url)
res
# Out:
# <Response [200]>

# %%
html = res.text
len(html)
# Out:
# 50305

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
tag_list = soup.select(".section_episode_list a")
len(tag_list)
# Out:
# 38

# %%
tag = tag_list
tag
# Out:
# [<a class="link" href="#">
#  <div class="thumbnail">
#  <img alt="3부 164화" height="45" src="https://image-comic.pstatic.net/webtoon/183559/583/thumbnail_202x120_39473d9d-0a9b-46bf-ad0d-3ab5d5485472.jpg" width="76"/>
#  <span class="ico_comic"><span class="blind">유료만화</span></span>
#  </div>
#  <div class="info">
#  <strong class="title">
#  <span class="name"><strong>3부 164화</strong></span>
#  </strong>
#  <div class="detail">
#  <span class="free_txt"></span>
#  <em class="free_time"></em>
#  </div>
#  </div>
#  <em class="cookie_txt"></em>
#  </a>,
#  <a class="link" href="#">
#  <div class="thumbnail">
#  <img alt="3부 163화" height="45" src="https://image-comic.pstatic.net/webtoon/183559/582/thumbnail_202x120_1325829a-dbc0-4e3e-81ee-70a151290333.jpg" width="76"/>
#  <span class="ico_comic"><span class="blind">유료만화</span></span>
#  </div>
#  <div class="info">
#  <strong class="title">
#  <span class="name"><strong>3부 163화</strong></span>
#  </strong>
#  <div class="detail">
# ...

# %%
webtoon_name = "신의탑"
number = (repr(tag.select(".name")[0].text))
idx = 1
f"{idx:3d}.jpg"
        
for idx, tag in  tqdm(enumerate(tag_list)):
    file_path = f"{webtoon_name}/{number}/{idx:03d}.jpg"
    print(file_path)
    
    dir_path = os.path.dirname(file_path)
    os.makedirs(dir_path, exist_ok = True)

    image_res = requests.get(tag["src"], headers=headers)
    assert image_res.status_code == 200, "서버 응답이 200이 아니에요!!"
    
    #저장
    with open(file_path, "wb") as f:
        f.write(image_res.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 6
#       3 idx = 1
#       4 f"{idx:3d}.jpg"
# ----> 6 for idx, tag in  tqdm(enumerate(tag_list)):
#       7     file_path = f"{webtoon_name}/{number}/{idx:03d}.jpg"
#       8     print(file_path)
#
# NameError: name 'tqdm' is not defined
