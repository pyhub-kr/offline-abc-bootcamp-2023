# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://m.comic.naver.com/webtoon/list?titleId=772764&week=fri&sortOrder=DESC&page=1"

res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3",
}

# %%
html = res.text
html
# Out:
# '\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t\n\n\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta http-equiv="Content-Type" content="text/html;charset=utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="format-detection" content="telephone=no">\n\n\n<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/comic/im/favicon/1804/webtoon_favicon_32x32.ico" type="image/x-icon">\n\n    \n    \n\n\n\t<title>죽지 않으려면 :: 네이버 웹툰</title>\n\t\n\n\n\n\n<meta property="og:title" content="죽지 않으려면" />\n\n    \n        \n        \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n            \n        \n            \n                \n            \n            \n        \n            \n            \n                \n            \n        \n            \n            \n        \n        \n            \n                \n            \n            \n        \n\n        \n            \n            \n                <meta property="og:image" content="https://shared-comic.pstatic.net/thumb/webtoon/772764/thumbnail/thumbnail_IMAG19_e5c188ff-a6ee-47e3-b93a-2883b3ec00b1.jpg" />\n            \n        \n        <meta property="og:description" content="고등학생 임다준은 학교에서 늘상 괴롭힘을 당하는 게 일상이었다. 삶을 포기하기 직전 우연히 본 티비 속 동급생 살해범의 인터뷰에 감명을 받고 복수를 결심하게 된다.복수는 성공했지만 삶은 원치않는 방향으로 흘러가게 되고.. 학교에서 나온 임다준은 범상치않은 가출팸에 들어가게 된다.가출청소년 임다준은 더이상 학교 안 일진들에게 시달리지 않게 되었지만 그보다 잔혹한 길거리의 양아치들을 상대로 살아남아야만 한다.삶의 끝자락에 내몰린 고등학생 임다준의 길거리 생존기!" />\n    \n    \n\n\n\t\n\n\n\n\n<meta property="og:type" content="article" />\n<meta property="og:url" content="" />\n<meta property="og:article:author" content="네이버 웹툰" />\n<meta property="og:article:author:url" content="http://m.comic.naver.com" />\n\n\t<meta name="csrf-token" content="b099dffb-37ec-49dc-af61-9c497a41f577"/>\n\t<link rel="stylesheet" type="text/css" href="/static/bundle/4ee4e8daa83a2e6fbf37.css">\n\t<script type="text/javascript">\n\t\tvar g_ssc = \'Mcomic.episode\';\n\t</script>\n</head>\n<body>\n<div id="u_skip" class="u_skip">\n\t<a href="#ct">본문 바로가기</a>\n</div>\n\n<header class="fixed">\n\t\n\n\n<h1 class="header_gnb">\n\t<a href="http://m.naver.com" onclick="nclk_v2(event,\'gnb.naver\')" class="gnb_logo"><span class="blind">네이버</span></a>\n\t<a href="/index" onclick="nclk_v2(event,\'gnb.comic\')" class="title_header_toon">웹툰</a>\n\t<a href="https://m.novel.naver.com" onclick="nclk_v2(event,\'gnb.novel\')" class="title_header_sub">웹소설</a>\n\t<a href="https://m.series.naver.com" onclick="nclk_v2(event, \'gnb.series\')" class="title_header_sub">시리즈</a>\n</h1>\n<a href="/search/main" onclick="nclk_v2(event,\'gnb.search\')" class="btn_search_header"><span class="blind">검색페이지 이동</span></a>\n<a href="/mypage/favorite" onclick="nclk_v2(event,\'gnb.my\')" class="btn_mypage_header"><span class="blind">MY</span></a>\n\n\t\n\n\n\n<!-- 그 외 기본 lnb -->\n<div class="lnb">\n    <ul class="list_lnb">\n        <li class="item "><a href="/index" onclick="nclk_v2(event,\'lnb.home\')" class="link"><span class="text">홈</span></a></li>\n        <li class="item on"><a href="/webtoon/weekday" onclick="nclk_v2(event,\'lnb.weekday\')" class="link"><span class="text">요일별</span></a></li>\n        <li class="item "><a href="/webtoon/finish" onclick="nclk_v2(event,\'lnb.finish\')" class="link"><span class="text">완결작</span></a></li>\n        <li class="item "><a href="/bestChallenge/genre" onclick="nclk_v2(event,\'lnb.best\')" class="link"><span class="text">베스트도전</span></a></li>\n    </ul>\n    <h2 class="blind">\n        \n            \n      ...

# %%
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://ssl.pstatic.net/static/m/comic/im/favicon/1804/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>죽지 않으려면 :: 네이버 웹툰</title>
# <meta content="죽지 않으려면" property="og:title">
# <meta content="https://shared-comic.pstatic.net/thumb/webtoon/772764/thumbnail/thumbnail_IMAG19_e5c188ff-a6ee-47e3-b93a-2883b3ec00b1.jpg" property="og:image">
# <meta content="고등학생 임다준은 학교에서 늘상 괴롭힘을 당하는 게 일상이었다. 삶을 포기하기 직전 우연히 본 티비 속 동급생 살해범의 인터뷰에 감명을 받고 복수를 결심하게 된다.복수는 성공했지만 삶은 원치않는 방향으로 흘러가게 되고.. 학교에서 나온 임다준은 범상치않은 가출팸에 들어가게 된다.가출청소년 임다준은 더이상 학교 안 일진들에게 시달리지 않게 되었지만 그보다 잔혹한 길거리의 양아치들을 상대로 살아남아야만 한다.삶의 끝자락에 내몰린 고등학생 임다준의 길거리 생존기!" property="og:description">
# <meta content="article" property="og:type">
# <meta content="" property="og:url">
# <meta content="네이버 웹툰" property="og:article:author">
# <meta content="http://m.comic.naver.com" property="og:article:author:url">
# <meta content="b099dffb-37ec-49dc-af61-9c497a41f577" name="csrf-token"/>
# <link href="/static/bundle/4ee4e8daa83a2e6fbf37.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 		var g_ssc = 'Mcomic.episode';
# 	</script>
# </meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <div class="u_skip" id="u_skip">
# <a href="#ct">본문 바로가기</a>
# </div>
# <header class="fixed">
# <h1 class="header_gnb">
# <a class="gnb_logo" href="http://m.naver.com" onclick="nclk_v2(event,'gnb.naver')"><span class="blind">네이버</span></a>
# <a class="title_header_toon" href="/index" onclick="nclk_v2(event,'gnb.comic')">웹툰</a>
# <a class="title_header_sub" href="https://m.novel.naver.com" onclick="nclk_v2(event,'gnb.novel')">웹소설</a>
# <a class="title_header_sub" href="https://m.series.naver.com" onclick="nclk_v2(event, 'gnb.series')">시리즈</a>
# </h1>
# <a class="btn_search_header" href="/search/main" onclick="nclk_v2(event,'gnb.search')"><span class="blind">검색페이지 이동</span></a>
# <a class="btn_mypage_header" href="/mypage/favorite" onclick="nclk_v2(event,'gnb.my')"><span class="blind">MY</span></a>
# <!-- 그 외 기본 lnb -->
# <div class="lnb">
# <ul class="list_lnb">
# <li class="item"><a class="link" href="/index" onclick="nclk_v2(event,'lnb.home')"><span class="text">홈</span></a></li>
# <li class="item on"><a class="link" href="/webtoon/weekday" onclick="nclk_v2(event,'lnb.weekday')"><span class="text">요일별</span></a></li>
# <li class="item"><a class="link" href="/webtoon/finish" onclick="nclk_v2(event,'lnb.finish')"><span class="text">완결작</span></a></li>
# <li class="item"><a class="link" href="/bestChallenge/genre" onclick="nclk_v2(event,'lnb.best')"><span class="text">베스트도전</span></a></li>
# </ul>
# <h2 class="blind">
#
#
#             요일별
#
#
#
#
#     </h2>
# </div>
# <div class="area_sublnb lnb_weekday">
# <ul class="daylist">
# <li class="day"><a class="link" href="/webtoon/weekday?week=mon" onclick="nclk_v2(event,'dow.mon')">월</a></li>
# <li class="day"><a class="link" href="/webtoon/weekday?week=tue" onclick="nclk_v2(event,'dow.tue')">화</a></li>
# <li class="day"><a class="link" href="/webtoon/weekday?week=wed" onclick="nclk_v2(event,'dow.wed')">수</a></li>
# <li class="day"><a class="link" href="/webtoon/weekday?week=thu" onclick="nclk_v2(event,'dow.thu')">목</a></li>
# <li class="day on"><a class="link" href="/webtoon/weekday?week=fri" onclick="nclk_v2(event,'dow.fri')">금</a></li>
# <li class="day"><a class="link" href="/webtoon/weekday?week=sat" onclick="nclk_v2(event,'dow.sat')">토</a></li>
# <li class="day"><a class="link" href="/webtoon/weekday?week=sun" onclick="nclk_v2(event,'dow.sun')">일</a></li>
# <li class="day"><a class="link" href="/webtoon/weekday?week=dailyPlus" onclick="nclk_v2(event,'dow.daily')">매일+</a></li>
# </ul>
# <h3 class="blind">금요일</h3>
# </div>
# </header>
# <!-- ct  -->
# <div id="ct" style="padding-top: 124px;">
# <div class="section_toon_info" style="background-color:#f7c2b5">
# <div class="info_front is_active">
# <h2 class="blind">작품 기본 정보</h2>
# <div class="area_info">
# <span class="summary">삶의 끝자락에 내몰린 고등학생</span>
# <strong class="title">죽지 않으려면</strong>
# <span class="author">파래 / 임진국</span>
# <span class="detail">
# <span class="ico_comic ico_score"><span class="blind">별점</span></span>
# <span class="score">9.90</span>
# <span class="favcount">관심 <span class="count_num">10만</span>
# <span class="count_plus">+</span>
# </span>
# </span>
# </div>
# <div class="area_thumbnail">
# <img alt="죽지 않으려면" height="174" src="https://image-comic.pstatic.net/webtoon/772764/thumbnail/titledescimage/frontImage_742d0f68-0e02-47f1-a638-0c5d3425885c.png" width="218"/>
# <div class="thumb_bg">
# <img alt="죽지 않으려면" height="174" src="https://image-comic.pstatic.net/webtoon/772764/thumbnail/titledescimage/objectImage_92a6d08b-5712-43b4-a388-91a1cd165510.png" width="250"/>
# </div>
# </div>
# <div class="area_etc">
# <a class="btn naver-splugin spi_sns_share sns_share" data-oninitialize="getInitialParams();" href="#" id="spiButton" onclick="nclk_v2(event,'LIC.expo')"><span class="btn_share"><span class="blind">공유하기</span></span></a>
# </div>
# </div>
# <div class="info_back">
# <h2 class="blind">작품 상세 정보</h2>
# <dl class="detail">
# <div class="author">
# <dt>작가</dt>
# <dd>
# <ul class="list_detail authorList">
# <li><a class="authorList" href="#">파래 / 임진국</a></li>
# </ul>
# </dd>
# </div>
# <div class="genre">
# <dt>장르</dt>
# <dd>
# <span class="length">스토리</span>
# <ul class="property list_detail">
# <li>액션</li>
# </ul>
# </dd>
# </div>
# <div class="week_day">
# <dt>연재</dt>
# <dd>
# <ul class="list_detail">
# <li>금</li>
# </ul>
# <ul class="property list_detail age">
# <li>15세 이용가</li>
# </ul>
# </dd>
# </div>
# </dl>
# <div class="summary"><p>고등학생 임다준은 학교에서 늘상 괴롭힘을 당하는 게 일상이었다. 삶을 포기하기 직전 우연히 본 티비 속 동급생 살해범의 인터뷰에 감명을 받고 복수를 결심하게 된다. 복수는 성공했지만 삶은 원치않는 방향으로 흘러가게 되고.. 학교에서 나온 임다준은 범상치않은 가출팸에 들어가게 된다. 가출청소년 임다준은 더이상 학교 안 일진들에게 시달리지 않게 되었지만 그보다 잔혹한 길거리의 양아치들을 상대로 살아남아야만 한다.  삶의 끝자락에 내몰린 고등학생 임다준의 길거리 생존기!</p></div>
# </div>
# <div class="paging"></div>
# </div>
# <ul class="section_toon_btn">
# <li class="item"><input id="prefer1" type="checkbox"/><label for="prefer1"><span class="ico_comic ico_plus"></span><em class="favorite">관심</em></label></li>
# <li class="item">
# <a class="link _first_article_link" data-article-no="1" data-inspection-status="NORMAL" href="#" onclick="nclk_v2(event,'LIC.first')"><em class="first_epi">첫화보기</em></a>
# </li>
# </ul>
# <div class="section_episode_count">
# <h3 class="title_count">
#
#
# 				총 <span class="count_num">98</span>화
#
# 		</h3>
# <div class="tablist" role="tablist">
# <button aria-selected="true" class="tab" data-sort-order="DESC" role="tab" type="button">최신화부터</button>
# <button aria-selected="false" class="tab" data-sort-order="ASC" role="tab" type="button"><span class="count_num">1</span>화부터</button>
# </div>
# </div>
# <div class="toon_preview">
# <a class="detail_more" href="#">
# <span class="txt"><em>5개</em>의 미리보기가 있습니다</span>
# <ul class="preview_thumb_lst">
# <li>
# <span class="icon_new"><span class="blind">new</span></span>
# <span class="thumb" style="background-image:url(https://image-comic.pstatic.net/webtoon/772764/94/thumbnail_202x120_f95cf040-0de7-4706-a49b-601d548605a3.jpg);"></span>
# </li>
# <li>
# <span class="thumb" style="background-image:url(https://image-comic.pstatic.net/webtoon/772764/95/thumbnail_202x120_50558fd4-eab5-4036-9d3a-aa26b62fe4ba.jpg);"></span>
# </li>
# <li>
# <span class="thumb" style="background-image:url(https://image-comic.pstatic.net/webtoon/772764/96/thumbnail_202x120_bfb535ee-7afa-4b80-b956-13c8fe4918ab.jpg);"></span>
# </li>
# </ul>
# <span class="ico_comic"><span class="blind">펼치기</span></span>
# </a>
# <ul class="section_episode_list">
# <li class="item lock" data-contents-no="433708" data-free-convert-date="1692885000000" data-no="98" data-title-id="772764" data-volume-no="98">
# <a class="link" href="#">
# <div class="thumbnail">
# <img alt="시즌2 28화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/98/thumbnail_202x120_7a4cf00e-a509-4cc1-bc4f-ab969462e36c.jpg" width="76"/>
# <span class="ico_comic"><span class="blind">유료만화</span></span>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 28화</strong></span>
# </strong>
# <div class="detail">
# <span class="free_txt"></span>
# <em class="free_time"></em>
# </div>
# </div>
# <em class="cookie_txt"></em>
# </a>
# </li>
# <li class="item lock" data-contents-no="433708" data-free-convert-date="1692280200000" data-no="97" data-title-id="772764" data-volume-no="97">
# <a class="link" href="#">
# <div class="thumbnail">
# <img alt="시즌2 27화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/97/thumbnail_202x120_9de643ec-8800-41c3-b95a-5c350fbf7118.jpg" width="76"/>
# <span class="ico_comic"><span class="blind">유료만화</span></span>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 27화</strong></span>
# </strong>
# <div class="detail">
# <span class="free_txt"></span>
# <em class="free_time"></em>
# </div>
# </div>
# <em class="cookie_txt"></em>
# </a>
# </li>
# <li class="item lock" data-contents-no="433708" data-free-convert-date="1691675400000" data-no="96" data-title-id="772764" data-volume-no="96">
# <a class="link" href="#">
# <div class="thumbnail">
# <img alt="시즌2 26화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/96/thumbnail_202x120_bfb535ee-7afa-4b80-b956-13c8fe4918ab.jpg" width="76"/>
# <span class="ico_comic"><span class="blind">유료만화</span></span>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 26화</strong></span>
# </strong>
# <div class="detail">
# <span class="free_txt"></span>
# <em class="free_time"></em>
# </div>
# </div>
# <em class="cookie_txt"></em>
# </a>
# </li>
# <li class="item lock" data-contents-no="433708" data-free-convert-date="1691070600000" data-no="95" data-title-id="772764" data-volume-no="95">
# <a class="link" href="#">
# <div class="thumbnail">
# <img alt="시즌2 25화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/95/thumbnail_202x120_50558fd4-eab5-4036-9d3a-aa26b62fe4ba.jpg" width="76"/>
# <span class="ico_comic"><span class="blind">유료만화</span></span>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 25화</strong></span>
# </strong>
# <div class="detail">
# <span class="free_txt"></span>
# <em class="free_time"></em>
# </div>
# </div>
# <em class="cookie_txt"></em>
# </a>
# </li>
# <li class="item lock" data-contents-no="433708" data-free-convert-date="1690465800000" data-no="94" data-title-id="772764" data-volume-no="94">
# <a class="link" href="#">
# <div class="thumbnail">
# <img alt="시즌2 24화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/94/thumbnail_202x120_f95cf040-0de7-4706-a49b-601d548605a3.jpg" width="76"/>
# <span class="ico_comic"><span class="blind">유료만화</span></span>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 24화</strong></span>
# </strong>
# <div class="detail">
# <span class="free_txt"></span>
# <em class="free_time"></em>
# </div>
# </div>
# <em class="cookie_txt"></em>
# </a>
# </li>
# </ul>
# </div>
# <ul class="section_episode_list preview">
# <li class="item" data-no="93" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=93&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','1')">
# <div class="thumbnail">
# <img alt="시즌2 23화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/93/thumbnail_202x120_bfad671f-d30e-408c-8d8f-057366b5c0ee.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 23화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.79</span>
# <span class="date">23.07.20</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="92" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=92&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','2')">
# <div class="thumbnail">
# <img alt="시즌2 22화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/92/thumbnail_202x120_6ec4fad8-4e2b-4237-a2b0-b6490b0ddf29.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 22화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.91</span>
# <span class="date">23.07.13</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="91" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=91&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','3')">
# <div class="thumbnail">
# <img alt="시즌2 21화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/91/thumbnail_202x120_6ffd55b4-1bf3-4139-a8cb-8d39a0f7e76e.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 21화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">23.07.06</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="90" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=90&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','4')">
# <div class="thumbnail">
# <img alt="시즌2 20화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/90/thumbnail_202x120_3e6b5a3e-10a9-4472-b5b0-3270dcce1585.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 20화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">23.06.29</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="89" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=89&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','5')">
# <div class="thumbnail">
# <img alt="시즌2 19화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/89/thumbnail_202x120_20717ca8-f17c-48b6-914f-2fcf2063895d.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 19화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.96</span>
# <span class="date">23.06.22</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="88" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=88&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','6')">
# <div class="thumbnail">
# <img alt="시즌2 18화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/88/thumbnail_202x120_f9f9c0c0-40e7-4fb8-9778-adb0c7657236.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 18화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.93</span>
# <span class="date">23.06.15</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="87" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=87&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','7')">
# <div class="thumbnail">
# <img alt="시즌2 17화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/87/thumbnail_202x120_c59b21ea-adce-46b9-8165-fff7d50bbf94.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 17화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.94</span>
# <span class="date">23.06.08</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="86" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=86&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','8')">
# <div class="thumbnail">
# <img alt="시즌2 16화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/86/thumbnail_202x120_bc44d61c-7130-45f6-bd62-fe7514192c57.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 16화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.90</span>
# <span class="date">23.06.01</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="85" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=85&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','9')">
# <div class="thumbnail">
# <img alt="시즌2 15화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/85/thumbnail_202x120_8354eb54-b08c-491d-9d05-a3ab76de94d5.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 15화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">23.05.25</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="84" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=84&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','10')">
# <div class="thumbnail">
# <img alt="시즌2 14화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/84/thumbnail_202x120_3a58d2ba-1052-40da-9863-205ea6f8e179.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 14화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.92</span>
# <span class="date">23.05.18</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="83" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=83&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','11')">
# <div class="thumbnail">
# <img alt="시즌2 13화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/83/thumbnail_202x120_3eb205b5-60ce-4cd2-a47b-b9f6e567cd74.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 13화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.96</span>
# <span class="date">23.05.11</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="82" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=82&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','12')">
# <div class="thumbnail">
# <img alt="시즌2 12화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/82/thumbnail_202x120_ec678405-9f3d-4cdf-a8f8-c3a87436199f.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 12화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">23.05.04</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="81" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=81&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','13')">
# <div class="thumbnail">
# <img alt="시즌2 11화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/81/thumbnail_202x120_ae28a97f-30c2-4f99-8372-447f90a66494.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 11화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.94</span>
# <span class="date">23.04.27</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="80" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=80&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','14')">
# <div class="thumbnail">
# <img alt="시즌2 10화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/80/thumbnail_202x120_c95c345c-f57a-4ae1-8a86-ce64d1683c10.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 10화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.93</span>
# <span class="date">23.04.20</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="79" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=79&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','15')">
# <div class="thumbnail">
# <img alt="시즌2 9화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/79/thumbnail_202x120_16ec5fb1-63f2-4ceb-a4b4-58a6220b8834.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 9화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.92</span>
# <span class="date">23.04.13</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="78" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=78&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','16')">
# <div class="thumbnail">
# <img alt="시즌2 8화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/78/thumbnail_202x120_19ee2bd2-c399-4c78-bcf9-f3598b5d0b53.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 8화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.96</span>
# <span class="date">23.04.06</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="77" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=77&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','17')">
# <div class="thumbnail">
# <img alt="시즌2 7화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/77/thumbnail_202x120_603b03f8-0c14-4def-bdd4-5609bad42abb.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 7화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.92</span>
# <span class="date">23.03.30</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="76" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=76&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','18')">
# <div class="thumbnail">
# <img alt="시즌2 6화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/76/thumbnail_202x120_55c889d6-0646-4ef2-bd04-dbd6b75faef8.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 6화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.96</span>
# <span class="date">23.03.23</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="75" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=75&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','19')">
# <div class="thumbnail">
# <img alt="시즌2 5화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/75/thumbnail_202x120_719652a9-7769-4e45-a9af-78c1be190230.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 5화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">23.03.16</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="74" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=74&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','20')">
# <div class="thumbnail">
# <img alt="시즌2 4화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/74/thumbnail_202x120_36668ff2-8101-45f2-8ab4-269253e69131.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 4화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.97</span>
# <span class="date">23.03.09</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="73" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=73&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','21')">
# <div class="thumbnail">
# <img alt="시즌2 3화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/73/thumbnail_202x120_9e3b7a4c-48d4-432a-afbb-2b8871cbc394.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 3화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">23.03.02</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="72" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=72&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','22')">
# <div class="thumbnail">
# <img alt="시즌2 2화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/72/thumbnail_202x120_ce90ae7a-5cb0-4fde-8484-92a82cb93aad.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 2화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.96</span>
# <span class="date">23.02.23</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="71" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=71&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','23')">
# <div class="thumbnail">
# <img alt="시즌2 1화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/71/thumbnail_202x120_a5964773-51d5-4625-ac7e-ca381a17b6b4.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>시즌2 1화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.96</span>
# <span class="date">23.02.16</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="70" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=70&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','24')">
# <div class="thumbnail">
# <img alt="특별편 4화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/70/thumbnail_202x120_7be1374e-29d7-4269-94f9-97729024129d.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>특별편 4화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">22.09.15</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="69" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=69&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','25')">
# <div class="thumbnail">
# <img alt="특별편 3화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/69/thumbnail_202x120_f99ae697-aae6-445b-8a3d-7cf92d250020.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>특별편 3화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">22.09.08</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="68" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=68&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','26')">
# <div class="thumbnail">
# <img alt="특별편 2화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/68/thumbnail_202x120_e030f693-7675-4737-b477-286cdbbcffe6.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>특별편 2화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.93</span>
# <span class="date">22.09.01</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="67" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=67&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','27')">
# <div class="thumbnail">
# <img alt="특별편 1화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/67/thumbnail_202x120_c942484e-dc38-474f-9a9a-c780107000b5.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>특별편 1화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.95</span>
# <span class="date">22.08.25</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="66" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=66&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','28')">
# <div class="thumbnail">
# <img alt="66화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/66/thumbnail_202x120_8cd2b8b0-3cb9-4d06-9153-2de185e75290.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>66화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.94</span>
# <span class="date">22.08.18</span>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="65" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=65&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','29')">
# <div class="thumbnail">
# <img alt="65화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/65/thumbnail_202x120_d4ba6433-e149-4438-97c1-1674cbccbf4c.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>65화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.89</span>
# <span class="date">22.08.11</span>
# <em class="ico_bgm">배경음악 있음</em>
# </div>
# </div>
# </a>
# </li>
# <li class="item" data-no="64" data-title-id="772764">
# <a class="link" href="/webtoon/detail?titleId=772764&amp;no=64&amp;week=fri&amp;listSortOrder=DESC&amp;listPage=1" onclick="nclk_v2(event,'lst.episode','772764','30')">
# <div class="thumbnail">
# <img alt="64화" height="45" src="https://image-comic.pstatic.net/webtoon/772764/64/thumbnail_202x120_587c0ae5-a5d1-41d0-acf9-7260a43f37a7.jpg" width="76"/>
# </div>
# <div class="info">
# <strong class="title">
# <span class="name"><strong>64화</strong></span>
# </strong>
# <div class="detail">
# <span class="ico_comic ico_score"></span>
# <span class="score">9.76</span>
# <span class="date">22.08.04</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# <div class="paging_type2">
# <a class="btn_prev disabled" href="#" onclick="return false"><span class="blind">이전 페이지</span></a>
# <em class="current_pg">1<span class="total">4</span></em>
# <a class="btn_next" href="/webtoon/list?titleId=772764&amp;week=fri&amp;sortOrder=DESC&amp;page=2" onclick="nclk_v2(event,'lst.next')"><span class="blind">다음 페이지</span></a>
# </div>
# <div class="service_info">
# <div class="service_info_tit">
# <strong>유료이용안내</strong>
# <a class="service_more" data-nbooks-id="433708" href="#">자세히보기</a>
# </div>
# <div class="service_info_detail"></div>
# </div>
# </div>
# <div class="ly_wrap" id="favoriteLayer" style="display:none">
# <div class="ly_cont favorite_add" style="display:none">
# <p class="tit">관심 웹툰에 등록되었습니다.</p>
# <div class="download">
# <span class="logo"><img alt="" src="https://ssl.pstatic.net/static/m/comic/im/ico_favorite_170602.png"/></span>
# <span class="app">
# <em>업데이트 소식을 놓치고 싶지 않다면?</em>
# <a href="/external/appLaunchBridge?type=ARTICLE_LIST&amp;titleId=772764">웹툰앱으로 보기</a>
# </span>
# </div>
# <div class="btn_area">
# <a href="#">확인</a>
# </div>
# </div>
# <div class="ly_cont favorite_cancle" style="display:none">
# <p class="tit">관심 웹툰이 취소되었습니다.</p>
# <div class="btn_area">
# <a href="#">확인</a>
# </div>
# </div>
# </div>
# <div class="dimmed_layer" style="display:none"></div>
# <!-- footer -->
# <div class="info_bottom">
# <div class="desc_bottom">
# </div>
# <footer class="footer">
# <a class="cont_app_banner" data-android-package="com.nhn.android.webtoon" data-android-scheme-prefix="webtoonkr" data-android-scheme-query="contentList?version=2&amp;titleId=772764&amp;league=WEBTOON" data-ios-install-id="315795555" data-ios-scheme-prefix="webtoonkr" data-ios-scheme-query="contentList?version=2&amp;titleId=772764&amp;league=WEBTOON" data-ios-universal="https://apps.comic.naver.com/launchApp/" data-nclick="fot.appbansave" data-unknown-url="https://comic.naver.com/webtoon/list?titleId=772764" href="#">
# <img alt="데이터 걱정 없이 감상하려면 임시저장 해보세요~ 웹툰앱 바로가기" class="app_banner" src="https://ssl.pstatic.net/static/m/comic/im/app_banner_list.jpg"/>
# </a>
# <ul class="list_link">
# <li class="link_site"><a href="/index" onclick="nclk_v2(event,'fot.webtoonweb')">웹툰</a></li>
# <li class="link_site"><a href="https://m.novel.naver.com" onclick="nclk_v2(event,'fot.novel')">웹소설</a></li>
# <li class="link_site"><a href="https://m.series.naver.com" onclick="nclk_v2(event,'fot.series')">시리즈</a></li>
# <li class="link_site"><a href="https://m.serieson.naver.com" onclick="nclk_v2(event,'fot.serieson')">시리즈온</a></li>
# </ul>
# <div class="foot_info">
# <div class="list_relative">
# <ul>
# <li class="link_relative">
# <a href="#" id="link_footer_login" onclick="nclk_v2(event,'fot.login')">로그인</a>
# </li>
# <li class="link_relative"><a class="link_rel" href="https://comic.naver.com/webtoon/list?titleId=772764&amp;mobile=y" onclick="nclk_v2(event,'fot.gopc')">PC버전</a></li>
# <li class="link_relative"><a class="link_rel" href="http://m.naver.com/services.html?f=svc.comic" onclick="nclk_v2(event,'fot.sitemap')">전체서비스</a></li>
# </ul>
# </div>
# <!-- [D] 활성화시 on클래스 추가-->
# <div class="biz_info">
# <button class="btn_biz_info" type="button">네이버웹툰(유) 사업자 정보</button>
# <div class="biz_info_detail">
# <ul>
# <li>사업자 등록번호 : 669-86-01888</li>
# <li>통신판매업 신고번호 : 2020-성남분당B-0719</li>
# <li>대표이사 : 김준구</li>
# <li>주소 : 경기도 성남시 분당구 분당내곡로 131 판교테크원 타워1, 11-12층</li>
# <li>고객센터 : 1588-3820</li>
# <li>이메일 : ccnaver@naver.com</li>
# </ul>
# <a class="lnk_biz_info" href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=6698601888">사업자 등록정보</a>
# </div>
# </div>
# <p class="txt_footer">모든 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며,<br/> 이를 무단으로 이용하는 경우 관련 법령에 따라 법적 책임을 질 수 있습니다.</p>
# <div class="info_relative">
# <ul>
# <li><a href="https://member.webtoon.naver.com/mobile/policies/terms/" onclick="nclk_v2(event,'fot.wagreement')">네이버웹툰 이용약관</a></li>
# <li><a href="https://m.comic.naver.com/store/comic/common/passJoinAgreeContract" onclick="nclk_v2(event,'fot.cooterms')">전용상품권 이용약관</a></li>
# <li><a class="privacy" href="https://member.webtoon.naver.com/mobile/policies/privacy/" onclick="nclk_v2(event,'fot.wprivacy')">개인정보처리방침</a></li>
# <li><a href="https://member.webtoon.naver.com/mobile/policies/youthpolicy/" onclick="nclk_v2(event,'fot.youthpolicy')">청소년보호정책</a></li>
# <li><a href="https://help.naver.com/service/5635?lang=ko" onclick="nclk_v2(event,'fot.whelp')">웹툰 고객센터</a></li>
# <li><a href="https://help.naver.com/alias/contents2/comic/webtoon_1.naver" onclick="nclk_v2(event,'fot.wclaim')">오류신고</a></li>
# </ul>
# <address><a class="webtoon_corp_link" href="https://webtoonscorp.com" onclick="nclk_v2(event,'fot.wtcorp')"><span class="blind">© NAVER WEBTOON Limited</span></a></address>
# </div>
# <div class="info_relative v2">
# <ul>
# <li><a href="http://policy.naver.com/policy-mobile/term.html" onclick="nclk_v2(event,'fot.agreement')">이용약관</a></li>
# <li><a class="privacy" href="http://m.policy.naver.com/privacy.html" onclick="nclk_v2(event,'fot.privacy')">개인정보처리방침</a></li>
# <li><a href="https://help.naver.com/index.help" onclick="nclk_v2(event,'fot.help')">고객센터</a></li>
# <li><a href="https://m.help.pay.naver.com/mailform.help?alias=embezzlement" onclick="nclk_v2(event,'fot.claim')">결제도용신고</a></li>
# <li><a href="https://cpc.naver.com/cpc/index.nhn" onclick="nclk_v2(event,'fot.cpchelp')">저작권침해신고</a></li>
# </ul>
# <address><a href="http://www.navercorp.com" onclick="nclk_v2(event,'fot.navercorp')"><span class="naver_corp_link"><span class="blind">© NAVER CORP.</span></span></a></address>
# </div>
# <a class="btn_top" href="#" id="goTopBtn" onclick="nclk_v2(event,'fot.top');"><span class="blind">TOP</span></a>
# </div>
# </footer>
# </div>
# <script>
# 	var ageRate = '';
# </script>
# <script type="text/javascript">
#     (function() {
#         window.__state__ = {
#             login: false,
#             idNo: '',
#             title: {
#                 titleId: 772764,
# 				webtoonLevelCode: 'WEBTOON',
#                 titleName: '죽지 않으려면',
#                 painterName: '임진국',
#                 finished: false,
# 				dailyPass: false,
#                 webtoonType: 'DEFAULT'
#             },
#             readArticles: '',
#             recentlyNo: 0,
#             weekdayTabQueryParam: 'fri',
#             sortOrder: 'DESC',
#             serviceDomain: location.protocol + '//' + location.hostname,
#             snsShare: {
#                 socialPluginJsDomain: 'https://ssl.pstatic.net/spi'
#             },
#             ad: {
#
#             },
#             hid: '',
#             levelPath: 'webtoon',
#
#         };
#     })();
# </script>
# <script src="/static/bundle/common-2175fc1553bba3cbc442.js" type="text/javascript"></script>
# <script src="/static/bundle/vendor-4a3f8ab172c5b29e10c9.js" type="text/javascript"></script>
# <script src="/static/bundle/article-list-e6b6dea698274f9058bf.js" type="text/javascript"></script>
# </body>
# </html>

# %%
title_list = soup.select('span.name strong')  # .select 는 태그 리스트를 반환
len(title_list)
# Out:
# 35

# %%
item_tags = soup.select('li.item')

url_save = []

for item_tag in item_tags:
    title_tag = item_tag.select_one('span.name strong') #각 회차마다의 제목 추출
    if title_tag:
        title = title_tag.get_text()
        print(title)
    url_tag = item_tag.select_one('a')   # 각 회차마다의 link 추출
    if url_tag:
        url = url_tag['href']
        url_save.append(url)              # 추출하는 url를 리스트에 저장
        print(url)
# Out:
# /index
# /webtoon/weekday
# /webtoon/finish
# /bestChallenge/genre
# #
# 시즌2 28화
# #
# 시즌2 27화
# #
# 시즌2 26화
# #
# 시즌2 25화
# #
# 시즌2 24화
# #
# 시즌2 23화
# /webtoon/detail?titleId=772764&no=93&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 22화
# /webtoon/detail?titleId=772764&no=92&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 21화
# /webtoon/detail?titleId=772764&no=91&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 20화
# /webtoon/detail?titleId=772764&no=90&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 19화
# /webtoon/detail?titleId=772764&no=89&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 18화
# /webtoon/detail?titleId=772764&no=88&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 17화
# /webtoon/detail?titleId=772764&no=87&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 16화
# /webtoon/detail?titleId=772764&no=86&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 15화
# /webtoon/detail?titleId=772764&no=85&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 14화
# /webtoon/detail?titleId=772764&no=84&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 13화
# /webtoon/detail?titleId=772764&no=83&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 12화
# /webtoon/detail?titleId=772764&no=82&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 11화
# /webtoon/detail?titleId=772764&no=81&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 10화
# /webtoon/detail?titleId=772764&no=80&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 9화
# /webtoon/detail?titleId=772764&no=79&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 8화
# /webtoon/detail?titleId=772764&no=78&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 7화
# /webtoon/detail?titleId=772764&no=77&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 6화
# /webtoon/detail?titleId=772764&no=76&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 5화
# /webtoon/detail?titleId=772764&no=75&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 4화
# /webtoon/detail?titleId=772764&no=74&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 3화
# /webtoon/detail?titleId=772764&no=73&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 2화
# /webtoon/detail?titleId=772764&no=72&week=fri&listSortOrder=DESC&listPage=1
# 시즌2 1화
# /webtoon/detail?titleId=772764&no=71&week=fri&listSortOrder=DESC&listPage=1
# 특별편 4화
# /webtoon/detail?titleId=772764&no=70&week=fri&listSortOrder=DESC&listPage=1
# 특별편 3화
# /webtoon/detail?titleId=772764&no=69&week=fri&listSortOrder=DESC&listPage=1
# 특별편 2화
# /webtoon/detail?titleId=772764&no=68&week=fri&listSortOrder=DESC&listPage=1
# 특별편 1화
# /webtoon/detail?titleId=772764&no=67&week=fri&listSortOrder=DESC&listPage=1
# 66화
# /webtoon/detail?titleId=772764&no=66&week=fri&listSortOrder=DESC&listPage=1
# 65화
# /webtoon/detail?titleId=772764&no=65&week=fri&listSortOrder=DESC&listPage=1
# 64화
# /webtoon/detail?titleId=772764&no=64&week=fri&listSortOrder=DESC&listPage=1

# %%
url_save_end = []       
for i in range(len(url_save)):     # 리스트 중 '/webtoon/detail'로 시작하는 정상적인 link 문자열 원소만 다시 저장 
    if url_save[i].startswith("/webtoon/detail?"):
        url_save_end.append(url_save[i])

# %%
url_save_end
# Out:
# ['/webtoon/detail?titleId=772764&no=93&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=92&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=91&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=90&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=89&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=88&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=87&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=86&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=85&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=84&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=83&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=82&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=81&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=80&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=79&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=78&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=77&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=76&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=75&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=74&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=73&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=72&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=71&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=70&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=69&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=68&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=67&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=66&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=65&week=fri&listSortOrder=DESC&listPage=1',
#  '/webtoon/detail?titleId=772764&no=64&week=fri&listSortOrder=DESC&listPage=1']

# %%
import os

filepath = "죽지않으려면/test.txt"  
dir_path = os.path.dirname(filepath)
dir_path
# Out:
# '죽지않으려면'

# %%
os.makedirs(dir_path)  # 부모 디렉토리 생성
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 os.makedirs(dir_path)  # 부모 디렉토리 생성
#
# File ~\anaconda3\envs\py3_8_5\lib\os.py:223, in makedirs(name, mode, exist_ok)
#     221         return
#     222 try:
# --> 223     mkdir(name, mode)
#     224 except OSError:
#     225     # Cannot rely on checking for EEXIST, since the operating system
#     226     # could give priority to other errors like EACCES or EROFS
#     227     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: '죽지않으려면'

# %%
import re
웹툰명 = "죽지않으려면"
cnt = 0

for i in title_list:  # 부모 폴더에 회차별 폴더를 생성하되 title_list를 순회하여 각 회차명를 파일명으로 기입하여 생성한다. 
    회차 = title_list[cnt].text
    print(회차)
    file_path = f"{웹툰명}/{회차}/test.txt"
    dirpath = os.path.dirname(file_path)  # 경로 계산하고, 없으면 생성
    os.makedirs(dirpath, exist_ok=True)
    cnt += 1
# Out:
# 시즌2 28화
# 시즌2 27화
# 시즌2 26화
# 시즌2 25화
# 시즌2 24화
# 시즌2 23화
# 시즌2 22화
# 시즌2 21화
# 시즌2 20화
# 시즌2 19화
# 시즌2 18화
# 시즌2 17화
# 시즌2 16화
# 시즌2 15화
# 시즌2 14화
# 시즌2 13화
# 시즌2 12화
# 시즌2 11화
# 시즌2 10화
# 시즌2 9화
# 시즌2 8화
# 시즌2 7화
# 시즌2 6화
# 시즌2 5화
# 시즌2 4화
# 시즌2 3화
# 시즌2 2화
# 시즌2 1화
# 특별편 4화
# 특별편 3화
# 특별편 2화
# 특별편 1화
# 66화
# 65화
# 64화

# %%
title_list_end = title_list[5:] # 쿠키를 구워야 볼 수 있는 유료회차분까지 추출되었기에 title_list에서 삭제
title_list_end[0]
# Out:
# <strong>시즌2 23화</strong>

# %%
page_url = "https://m.comic.naver.com/webtoon/list?titleId=772764&week=fri&sortOrder=DESC&page=1" 
res = requests.get(page_url)
html = res.text
soup = BeautifulSoup(html, "html.parser")
image_list = soup.select('') #반환값을 찾으려 이것저것 넣어봤지만 유의미한 숫자가 나오지 않았습니다.
len(image_list)
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[103], line 5
#       3 html = res.text
#       4 soup = BeautifulSoup(html, "html.parser")
# ----> 5 image_list = soup.select('') #반환값을 찾으려 이것저것 넣어봤지만 유의미한 숫자가 나오지 않았습니다.
#       6 len(image_list)
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\bs4\element.py:2111, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    2091 def select(self, selector, namespaces=None, limit=None, **kwargs):
#    2092     """Perform a CSS selection operation on the current element.
#    2093
#    2094     This uses the SoupSieve library.
#    (...)
#    2109     :rtype: bs4.element.ResultSet
#    2110     """
# -> 2111     return self.css.select(selector, namespaces, limit, **kwargs)
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\bs4\css.py:162, in CSS.select(self, select, namespaces, limit, flags, **kwargs)
#     158 if limit is None:
#     159     limit = 0
#     161 return self._rs(
# --> 162     self.api.select(
#     163         select, self.tag, self._ns(namespaces, select), limit, flags,
#     164         **kwargs
#     165     )
#     166 )
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\soupsieve\__init__.py:147, in select(select, tag, namespaces, limit, flags, custom, **kwargs)
#     135 def select(
#     136     select: str,
#     137     tag: 'bs4.Tag',
#    (...)
#     143     **kwargs: Any
#     144 ) -> list['bs4.Tag']:
#     145     """Select the specified tags."""
# --> 147     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\soupsieve\__init__.py:65, in compile(pattern, namespaces, flags, custom, **kwargs)
#      62         raise ValueError("Cannot process 'custom' argument on a compiled selector list")
#      63     return pattern
# ---> 65 return cp._cached_css_compile(
#      66     pattern,
#      67     ct.Namespaces(namespaces) if namespaces is not None else namespaces,
#      68     ct.CustomSelectors(custom) if custom is not None else custom,
#      69     flags
#      70 )
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\soupsieve\css_parser.py:219, in _cached_css_compile(pattern, namespaces, custom, flags)
#     214 """Cached CSS compile."""
#     216 custom_selectors = process_custom(custom)
#     217 return cm.SoupSieve(
#     218     pattern,
# --> 219     CSSParser(
#     220         pattern,
#     221         custom=custom_selectors,
#     222         flags=flags
#     223     ).process_selectors(),
#     224     namespaces,
#     225     custom,
#     226     flags
#     227 )
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\soupsieve\css_parser.py:1145, in CSSParser.process_selectors(self, index, flags)
#    1142 def process_selectors(self, index: int = 0, flags: int = 0) -> ct.SelectorList:
#    1143     """Process selectors."""
# -> 1145     return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#
# File ~\anaconda3\envs\py3_8_5\lib\site-packages\soupsieve\css_parser.py:1078, in CSSParser.parse_selectors(self, iselector, index, flags)
#    1073     has_selector = True
#    1075 if not has_selector:
#    1076     # We will always need to finish a selector when `:has()` is used as it leads with combining.
#    1077     # May apply to others as well.
# -> 1078     raise SelectorSyntaxError(
#    1079         'Expected a selector at position {}'.format(index),
#    1080         self.pattern,
#    1081         index
#    1082     )
#    1084 # Some patterns require additional logic, such as default. We try to make these the
#    1085 # last pattern, and append the appropriate flag to that selector which communicates
#    1086 # to the matcher what additional logic is required.
#    1087 if is_default:
#
# SelectorSyntaxError: Expected a selector at position 0
#   line 1:
#
# ^
